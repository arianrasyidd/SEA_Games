# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
page = requests.get("https://www2.2019seagames.com/countries/")
doc = BeautifulSoup(page.content, "html.parser")

output = []

for i in doc.find_all("em"):
    output.append(i.text)

output
# Out:
# ['BRUNEI DARUSALLAM',
#  'Total: 14',
#  'Gold: 0',
#  'Silver: 5',
#  'Bronze: 9',
#  'First Joined: 1977',
#  'CAMBODIA',
#  'Total: 17',
#  'Gold: 3',
#  'Silver: 2',
#  'Bronze: 12',
#  'First Joined: 1961',
#  'INDONESIA',
#  'Total: 191',
#  'Gold: 38',
#  'Silver: 63',
#  'Bronze: 90',
#  'First Joined: 1977',
#  'LAO PEOPLE’S DEMOCRATIC REPUBLIC',
#  'Total: 26',
#  'Gold: 2',
#  'Silver: 3',
#  'Bronze: 21',
#  'First Joined: 1959',
#  'MALAYSIA',
#  'Total: 323',
#  'Gold: 145',
#  'Silver: 92',
#  'Bronze: 86',
#  'First Joined: 1959',
#  'MYANMAR',
#  'Total: 37',
#  'Gold: 7',
#  'Silver: 10',
#  'Bronze: 20',
#  'First Joined: 1959',
#  'PHILIPPINES',
#  'Total: 121',
#  'Gold: 24',
#  'Silver: 33',
#  'Bronze: 64',
#  'First Joined: 1977',
#  'SINGAPORE',
#  'Total: 188',
#  'Gold: 57',
#  'Silver: 58',
#  'Bronze: 73',
#  'First Joined: 1959',
#  'THAILAND',
#  'Total: 246',
#  'Gold: 72',
#  'Silver: 86',
#  'Bronze: 88',
#  'First Joined: 1959',
#  'TIMOR LESTE',
# ...

# %%
country = output[::6]

country = country[0:11]

country
# Out:
# ['BRUNEI DARUSALLAM',
#  'CAMBODIA',
#  'INDONESIA',
#  'LAO PEOPLE’S DEMOCRATIC REPUBLIC',
#  'MALAYSIA',
#  'MYANMAR',
#  'PHILIPPINES',
#  'SINGAPORE',
#  'THAILAND',
#  'TIMOR LESTE',
#  'VIETNAM']

# %%
gold_raw = output[2::6]

gold_raw
# Out:
# ['Gold: 0',
#  'Gold: 3',
#  'Gold: 38',
#  'Gold: 2',
#  'Gold: 145',
#  'Gold: 7',
#  'Gold: 24',
#  'Gold: 57',
#  'Gold: 72',
#  'Gold: 0',
#  'Gold: 58',
#  'Gold: 0',
#  'Gold: 3',
#  'Gold: 38',
#  'Gold: 2',
#  'Gold: 145',
#  'Gold: 7',
#  'Gold: 24',
#  'Gold: 57',
#  'Gold: 72',
#  'Gold: 0',
#  'Gold: 58']

# %%
gold_raw1 = []
gold = []

for i in range(len(gold_raw)):
    temp = gold_raw[i].split(" ")
    gold_raw1.append(temp[1])
    
for j in range(len(gold_raw1)):
    temp = int(gold_raw1[j])
    gold.append(temp)
    
gold = gold[:11]

gold
# Out:
# [0, 3, 38, 2, 145, 7, 24, 57, 72, 0, 58]

# %%
page_medal = requests.get("https://rs.2019seagames.com/RS2019/mobiapp/MedalTally")
doc_medal = BeautifulSoup(page_medal.content, "html.parser")

output1 = []

for i in doc_medal.find_all("small"):
    output1.append(i.text)

output1
# Out:
# ['Contingent',
#  'Gold',
#  'Silver',
#  'Bronze',
#  'Total',
#  'PHILIPPINES',
#  '149',
#  '117',
#  '121',
#  '387',
#  'VIETNAM',
#  '98',
#  '85',
#  '105',
#  '288',
#  'THAILAND',
#  '92',
#  '103',
#  '123',
#  '318',
#  'INDONESIA',
#  '72',
#  '84',
#  '111',
#  '267',
#  'MALAYSIA',
#  '55',
#  '58',
#  '71',
#  '184',
#  'SINGAPORE',
#  '53',
#  '46',
#  '68',
#  '167',
#  'MYANMAR',
#  '4',
#  '18',
#  '51',
#  '73',
#  'CAMBODIA',
#  '4',
#  '6',
#  '36',
#  '46',
#  'BRUNEI DARUSSALAM',
#  '2',
#  '5',
#  '6',
#  '13',
#  'LAO PDR',
#  '1',
#  '5',
#  '29',
#  '35',
#  'TIMOR-LESTE',
#  '0',
#  '1',
#  '5',
#  '6']

# %%
out2 = output1[5:]

out2
# Out:
# ['PHILIPPINES',
#  '149',
#  '117',
#  '121',
#  '387',
#  'VIETNAM',
#  '98',
#  '85',
#  '105',
#  '288',
#  'THAILAND',
#  '92',
#  '103',
#  '123',
#  '318',
#  'INDONESIA',
#  '72',
#  '84',
#  '111',
#  '267',
#  'MALAYSIA',
#  '55',
#  '58',
#  '71',
#  '184',
#  'SINGAPORE',
#  '53',
#  '46',
#  '68',
#  '167',
#  'MYANMAR',
#  '4',
#  '18',
#  '51',
#  '73',
#  'CAMBODIA',
#  '4',
#  '6',
#  '36',
#  '46',
#  'BRUNEI DARUSSALAM',
#  '2',
#  '5',
#  '6',
#  '13',
#  'LAO PDR',
#  '1',
#  '5',
#  '29',
#  '35',
#  'TIMOR-LESTE',
#  '0',
#  '1',
#  '5',
#  '6']

# %%
country1 = out2[::5]

country1
# Out:
# ['PHILIPPINES',
#  'VIETNAM',
#  'THAILAND',
#  'INDONESIA',
#  'MALAYSIA',
#  'SINGAPORE',
#  'MYANMAR',
#  'CAMBODIA',
#  'BRUNEI DARUSSALAM',
#  'LAO PDR',
#  'TIMOR-LESTE']

# %%
gold1 = out2[1::5]

gold1
# Out:
# ['149', '98', '92', '72', '55', '53', '4', '4', '2', '1', '0']

# %%
all0 = list(zip(country, gold))
all0.sort()
all0
# Out:
# [('BRUNEI DARUSALLAM', 0),
#  ('CAMBODIA', 3),
#  ('INDONESIA', 38),
#  ('LAO PEOPLE’S DEMOCRATIC REPUBLIC', 2),
#  ('MALAYSIA', 145),
#  ('MYANMAR', 7),
#  ('PHILIPPINES', 24),
#  ('SINGAPORE', 57),
#  ('THAILAND', 72),
#  ('TIMOR LESTE', 0),
#  ('VIETNAM', 58)]

# %%
all1 = list(zip(country1, gold1))
all1.sort()
all1
# Out:
# [('BRUNEI DARUSSALAM', '2'),
#  ('CAMBODIA', '4'),
#  ('INDONESIA', '72'),
#  ('LAO PDR', '1'),
#  ('MALAYSIA', '55'),
#  ('MYANMAR', '4'),
#  ('PHILIPPINES', '149'),
#  ('SINGAPORE', '53'),
#  ('THAILAND', '92'),
#  ('TIMOR-LESTE', '0'),
#  ('VIETNAM', '98')]

# %%
country_all = []

for i in range(len(all1)):
    temp = all1[i]
    country_all.append(temp[0])

country_all
# Out:
# ['BRUNEI DARUSSALAM',
#  'CAMBODIA',
#  'INDONESIA',
#  'LAO PDR',
#  'MALAYSIA',
#  'MYANMAR',
#  'PHILIPPINES',
#  'SINGAPORE',
#  'THAILAND',
#  'TIMOR-LESTE',
#  'VIETNAM']

# %%
gold_2017 = []

for i in range(len(all0)):
    temp = all0[i]
    gold_2017.append(temp[1])

gold_2017
# Out:
# [0, 3, 38, 2, 145, 7, 24, 57, 72, 0, 58]

# %%
gold_2019 = []

for i in range(len(all1)):
    temp = all1[i]
    gold_2019.append(int(temp[1]))

gold_2019
# Out:
# [2, 4, 72, 1, 55, 4, 149, 53, 92, 0, 98]

# %%
plt.figure(figsize=(15,7))
plt.plot(country_all, gold_2017, "r-o")
plt.plot(country_all, gold_2019, "g-o")
plt.plot(country_all[gold_2017.index(max(gold_2017))], max(gold_2017), '*', markersize = 20, markerfacecolor = "yellow")
plt.plot(country_all[gold_2019.index(max(gold_2019))], max(gold_2019), '*', markersize = 20, markerfacecolor = "yellow")
plt.title('GOLD MEDAL TALLY SEA GAMES 2017 & 2019', fontsize = 30, pad = 60)
plt.xlabel('COUNTRY', fontsize = 20)
plt.ylabel('JUMLAH MEDALI', fontsize = 20)
plt.xticks(rotation = 25)
plt.legend(['Gold 2017', 'Gold 2019', 'Champion 2017', 'Champion 2019'], bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=4, mode="expand", borderaxespad=0.)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (15,7))
plt.subplot(1, 2, 1)
plt.pie(gold_2017, labels = country_all, autopct='%1.1f%%')
plt.title('%GOLD MEDAL TALLY SEA GAMES 2017', fontsize = 20)

plt.subplot(1, 2, 2)
plt.pie(gold_2019, labels = country_all, autopct='%1.1f%%')
plt.title('%GOLD MEDAL TALLY SEA GAMES 2019', fontsize = 20)
plt.show()
